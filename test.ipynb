# %%
s = "0P"
s_clean = ""
reversed_s = s_clean[::-1]
for i in range(len(s)):
    if s[i].isalpha():
        s_clean += s[i].lower()
print(s_clean)
# Out:
# p

# %%
original_string = s_clean
reversed_string = original_string[::-1]
print(reversed_string)  # Output: olleh
# Out:
# ammmmanaplanacanalpanama
